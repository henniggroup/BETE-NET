# %%
import torch_geometric as tg
import torch 
from utils.data import build_data, get_target, get_neighbors
from utils.training import get_model, train

import pandas as pd
import numpy as np

# %%
data_path = 'database.pkl'
df = pd.read_pickle(data_path)
df.dropna(inplace=True)

# %%
df.head()
# Out:
#       comp                                          structure  \
# 0       Cs             (Atom('Cs', [0.0, 0.0, 0.0], index=0))
# 1  AuInPdY  (Atom('Y', [0.0, 0.0, 0.0], index=0), Atom('In...
# 2   Pd2SnY  (Atom('Y', [-3.344924900585068, 3.344924900585...
# 3    Hg3Tl  (Atom('Tl', [0.0, 0.0, 0.0], index=0), Atom('H...
# 4   AuLiSb  (Atom('Li', [0.0, 0.0, 0.0], index=0), Atom('S...
#
#                                             Freq_meV  \
# 0  [0.2500020894237172, 0.3500026530791246, 0.450...
# 1  [0.2500020894237172, 0.3500026530791246, 0.450...
# 2  [0.2500020894237172, 0.3500026530791246, 0.450...
# 3  [0.2500020894237172, 0.3500026530791246, 0.450...
# 4  [0.2500020894237172, 0.3500026530791246, 0.450...
#
#                                                  a2F  \
# 0  [0.000393028, 0.00107847, 0.00229214, 0.004184...
# 1  [0.0030494, 0.00836756, 0.0177841, 0.03247, 0....
# 2  [0.000446282, 0.0012246, 0.00260272, 0.0047520...
# 3  [6.38383e-05, 0.000175172, 0.000372305, 0.0006...
# 4  [8.20164e-05, 0.000225053, 0.00047832, 0.00087...
#
#                                           PhFreq_meV  \
# 0  [-6.085040398332379e-08, 0.10000080571388359, ...
# 1  [-2.6987919082213373e-07, 0.10000059668510464,...
# 2  [-1.870816176469976e-07, 0.10000067948303153, ...
# 3  [-1.1853092944257293e-07, 0.10000074803268756,...
# 4  [-2.591243543263685e-07, 0.10000060743949912, ...
#
#                                            Tot_PhDOS  \
# 0  [0.0, 0.0020322211624833066, 0.008128885254687...
# 1  [0.0, 0.0008684808446008167, 0.003473923532455...
# 2  [0.0, 0.00029649550326095366, 0.00118598279430...
# 3  [0.0, 0.0009253369606325421, 0.003701350212266...
# 4  [0.0, 0.0002538770245085919, 0.001015509746453...
#
#                                      Site_Proj_PhDOS    lambda     w_log  \
# 0  [[0.0, 0.0020321934853404634, 0.00812925787376...  0.200493  2.004419
# 1  [[0.0, 0.0001485995109299599, 0.00057976715396...  2.387674  2.187430
# 2  [[0.0, 6.174332262652135e-05, 0.00024316796868...  2.142195  3.377658
# 3  [[0.0, 0.00023463462725051366, 0.0009387482130...  0.875469  3.744005
# 4  [[0.0, 5.403508594633448e-06, 2.15874180961809...  1.159056  3.959086
#
#          w_sq  ...                                   PhFreq_meV_dense  \
# 0    6.257714  ...  [-6.085040398332379e-08, 0.10000080571388359, ...
# 1   24.628668  ...  [-2.6987919082213373e-07, 0.10000059668510464,...
# 2   33.592206  ...  [-1.870816176469976e-07, 0.10000067948303153, ...
# 3   21.080808  ...  [-1.1853092944257293e-07, 0.10000074803268756,...
# 4  121.864371  ...  [-2.591243543263685e-07, 0.10000060743949912, ...
#
#                                      Tot_PhDOS_dense  \
# 0  [0.0, 0.0012481590493140242, 0.004758605329721...
# 1  [0.0, 3.643101440717545e-05, 0.000145724082212...
# 2  [0.0, 4.442308908471899e-05, 0.000177692694081...
# 3  [0.0, 0.000958242776325254, 0.0038329728614110...
# 4  [0.0, 8.94992325906488e-05, 0.0003579977356906...
#
#                                Site_Proj_PhDOS_dense  \
# 0  [[0.0, 0.0012481423315464227, 0.00475858800768...
# 1  [[0.0, 6.383229751421453e-06, 2.55177557902848...
# 2  [[0.0, 9.386675576437653e-06, 3.75176663613656...
# 3  [[0.0, 0.00024280501937882723, 0.0009706877518...
# 4  [[0.0, 1.906532370474594e-06, 7.62354850906416...
#
#                                     Tot_eDOS_eng_meV  \
# 0  [-59.90000000000029, -58.89999999999995, -57.9...
# 1  [-59.99999999999872, -59.00000000000105, -57.9...
# 2  [-59.00000000000105, -57.99999999999983, -57.0...
# 3  [-59.499999999999886, -58.50000000000044, -57....
# 4  [-59.499999999999886, -58.50000000000044, -57....
#
#                                             Tot_eDOS  \
# 0  [1.2210457884862193e-05, 1.2210457884862193e-0...
# 1  [2.3458147467037518e-05, 2.3458147467037518e-0...
# 2  [2.444904947840698e-05, 2.444904947840698e-05,...
# 3  [1.0029044003269802e-05, 1.012834146864871e-05...
# 4  [2.0600779540839817e-05, 2.0600779540839817e-0...
#
#                               Site_proj_eDOS_eng_meV  \
# 0  [-59.90000000000029, -58.89999999999995, -57.9...
# 1  [-59.99999999999872, -59.00000000000105, -57.9...
# 2  [-59.00000000000105, -57.99999999999983, -57.0...
# 3  [-59.499999999999886, -58.50000000000044, -57....
# 4  [-59.499999999999886, -58.50000000000044, -57....
#
#                                       Site_proj_eDOS  \
# 0  [[1.117835043145045e-05, 1.1270872400968928e-0...
# 1  [[9.043179593508906e-06, 9.04305210357702e-06,...
# 2  [[6.776663285157005e-06, 6.776396082430465e-06...
# 3  [[5.226121921433394e-06, 5.236053653920593e-06...
# 4  [[2.897737343721514e-07, 2.897578876186585e-07...
#
#                       Ph_2x2x2_interpolated_Freq_meV  \
# 0  [0.0, 0.10000086656411722, 0.20000173312823444...
# 1  [-5.031994663340724e-07, 0.10000036336409018, ...
# 2  [-3.5685336069797726e-07, 0.10000050971014814,...
# 3  [-6.10494434250373, -6.004943475939613, -5.904...
# 4  [-6.787491518144743e-07, 0.10000018781478023, ...
#
#                        Ph_2x2x2_interpolated_Tot_DOS  \
# 0  [0.0, 0.002723499688694547, 0.0108940020350333...
# 1  [0.0, 0.0001446230318617502, 0.000578493267341...
# 2  [0.0, 6.652902586054768e-05, 0.000266116923297...
# 3  [0.0, 0.44470284544261407, 0.5154988295465505,...
# 4  [0.0, 0.0030508291060651936, 0.012203344520247...
#
#                  Ph_2x2x2_interpolated_Site_Proj_DOS
# 0  [[0.0, 0.0027234909279048826, 0.01089412502242...
# 1  [[0.0, 2.5177389997772625e-05, 9.9996566245638...
# 2  [[0.0, 1.3975967897277166e-05, 5.5539309176275...
# 3  [[0.0, 0.0018224894425604506, 0.00330017704554...
# 4  [[0.0, 6.634390670351053e-05, 0.00027069565706...
#
# [5 rows x 22 columns]

# %%
r_max = 4
df['target'] = df.apply(get_target,axis=1)
df['formula'] = df['structure'].map(lambda x: x.get_chemical_formula())
df['species'] = df['structure'].map(lambda x: list(set(x.get_chemical_symbols())))
species = sorted(list(set(df['species'].sum())))

df['data'] = df.apply(build_data,embed_ph_dos=False,embed_e_dos=False,fine=False,r_max = r_max,axis=1)

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

out_dim = len(df.iloc[0]['target'])
in_dim = len(df.iloc[0].data.x[0])
em_dim = 64

# %%
init_dict_base = dict(in_dim=118,                           
    em_dim=em_dim,                        
    irreps_in=str(em_dim)+"x0e",          
    irreps_out=str(out_dim)+"x0e",        
    irreps_node_attr=str(em_dim)+"x0e",   
    layers=2,                             
    mul=32,                               
    lmax=1,                               
    max_radius=r_max,      
    num_neighbors=get_neighbors(df,df.index).mean(),      
    reduce_output=True,
    p=0.0
)

# %%
max_iter = 50

# %%
loss_fn = torch.nn.MSELoss()
loss_fn_mae = torch.nn.MSELoss()

# %%
folds = range(10)
for i in folds:
    idx_train = pd.Index(np.loadtxt(f'indices/idx_train_V2_{i}.txt'))
    idx_valid = pd.Index(np.loadtxt(f'indices/idx_valid_V2_{i}.txt'))
    
    dataloader_train = tg.loader.DataLoader(df.iloc[df.index.isin(idx_train)]['data'].values, batch_size=652)
    dataloader_valid = tg.loader.DataLoader(df.iloc[df.index.isin(idx_valid)]['data'].values, batch_size=164)
    name = f'models/CSO_test_{i}'
    
    run_name = f'{name}'
    print(name)

    model, opt, scheduler = get_model(init_dict_base,lr = 0.005,wd=0,device=device)

    train(model, opt, dataloader_train, dataloader_valid,
          loss_fn, loss_fn_mae, run_name,
          max_iter=max_iter, scheduler=scheduler, device=device)
# Out:
# models/CSO_test_0
# Validation loss decreased (inf --> 0.010310).  Saving model ...
# Validation loss decreased (0.010310 --> 0.010310).  Saving model ...
# Validation loss decreased (0.010310 --> 0.010309).  Saving model ...
# Validation loss decreased (0.010309 --> 0.010308).  Saving model ...
# Validation loss decreased (0.010308 --> 0.010307).  Saving model ...
# Validation loss decreased (0.010307 --> 0.010306).  Saving model ...
# Validation loss decreased (0.010306 --> 0.010304).  Saving model ...
# Validation loss decreased (0.010304 --> 0.010300).  Saving model ...
# Validation loss decreased (0.010300 --> 0.010296).  Saving model ...
# Validation loss decreased (0.010296 --> 0.010290).  Saving model ...
# Validation loss decreased (0.010290 --> 0.010281).  Saving model ...
# Validation loss decreased (0.010281 --> 0.010268).  Saving model ...
# Validation loss decreased (0.010268 --> 0.010248).  Saving model ...
# Validation loss decreased (0.010248 --> 0.010217).  Saving model ...
# Validation loss decreased (0.010217 --> 0.010167).  Saving model ...
# Validation loss decreased (0.010167 --> 0.010087).  Saving model ...
# Validation loss decreased (0.010087 --> 0.009954).  Saving model ...
# Validation loss decreased (0.009954 --> 0.009741).  Saving model ...
# Validation loss decreased (0.009741 --> 0.009415).  Saving model ...
# Validation loss decreased (0.009415 --> 0.009016).  Saving model ...
# Validation loss decreased (0.009016 --> 0.008885).  Saving model ...
# Validation loss decreased (0.008885 --> 0.008741).  Saving model ...
# Validation loss decreased (0.008741 --> 0.008331).  Saving model ...
# Validation loss decreased (0.008331 --> 0.008035).  Saving model ...
# Validation loss decreased (0.008035 --> 0.007835).  Saving model ...
# Validation loss decreased (0.007835 --> 0.007639).  Saving model ...
# Validation loss decreased (0.007639 --> 0.007483).  Saving model ...
# Validation loss decreased (0.007483 --> 0.007443).  Saving model ...
# Validation loss decreased (0.007443 --> 0.007363).  Saving model ...
# Validation loss decreased (0.007363 --> 0.007269).  Saving model ...
# Validation loss decreased (0.007269 --> 0.007254).  Saving model ...
# Validation loss decreased (0.007254 --> 0.007250).  Saving model ...
# Validation loss decreased (0.007250 --> 0.007215).  Saving model ...
# Validation loss decreased (0.007215 --> 0.007184).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# Validation loss decreased (0.007184 --> 0.007171).  Saving model ...
# Validation loss decreased (0.007171 --> 0.007138).  Saving model ...
# Validation loss decreased (0.007138 --> 0.007092).  Saving model ...
# Validation loss decreased (0.007092 --> 0.007018).  Saving model ...
# Validation loss decreased (0.007018 --> 0.006925).  Saving model ...
# Validation loss decreased (0.006925 --> 0.006835).  Saving model ...
# Validation loss decreased (0.006835 --> 0.006749).  Saving model ...
# Validation loss decreased (0.006749 --> 0.006671).  Saving model ...
# Validation loss decreased (0.006671 --> 0.006632).  Saving model ...
# Validation loss decreased (0.006632 --> 0.006611).  Saving model ...
# Validation loss decreased (0.006611 --> 0.006581).  Saving model ...
# Validation loss decreased (0.006581 --> 0.006563).  Saving model ...
# Validation loss decreased (0.006563 --> 0.006551).  Saving model ...
# EarlyStopping counter: 1 out of 15
# Validation loss decreased (0.006551 --> 0.006540).  Saving model ...
# models/CSO_test_1
# Validation loss decreased (inf --> 0.009475).  Saving model ...
# Validation loss decreased (0.009475 --> 0.009475).  Saving model ...
# Validation loss decreased (0.009475 --> 0.009475).  Saving model ...
# Validation loss decreased (0.009475 --> 0.009474).  Saving model ...
# Validation loss decreased (0.009474 --> 0.009474).  Saving model ...
# Validation loss decreased (0.009474 --> 0.009473).  Saving model ...
# Validation loss decreased (0.009473 --> 0.009472).  Saving model ...
# Validation loss decreased (0.009472 --> 0.009471).  Saving model ...
# Validation loss decreased (0.009471 --> 0.009469).  Saving model ...
# Validation loss decreased (0.009469 --> 0.009466).  Saving model ...
# Validation loss decreased (0.009466 --> 0.009463).  Saving model ...
# Validation loss decreased (0.009463 --> 0.009458).  Saving model ...
# Validation loss decreased (0.009458 --> 0.009451).  Saving model ...
# Validation loss decreased (0.009451 --> 0.009441).  Saving model ...
# Validation loss decreased (0.009441 --> 0.009427).  Saving model ...
# Validation loss decreased (0.009427 --> 0.009405).  Saving model ...
# Validation loss decreased (0.009405 --> 0.009373).  Saving model ...
# Validation loss decreased (0.009373 --> 0.009324).  Saving model ...
# Validation loss decreased (0.009324 --> 0.009248).  Saving model ...
# Validation loss decreased (0.009248 --> 0.009130).  Saving model ...
# Validation loss decreased (0.009130 --> 0.008951).  Saving model ...
# Validation loss decreased (0.008951 --> 0.008707).  Saving model ...
# Validation loss decreased (0.008707 --> 0.008473).  Saving model ...
# Validation loss decreased (0.008473 --> 0.008411).  Saving model ...
# Validation loss decreased (0.008411 --> 0.008200).  Saving model ...
# Validation loss decreased (0.008200 --> 0.007836).  Saving model ...
# Validation loss decreased (0.007836 --> 0.007522).  Saving model ...
# Validation loss decreased (0.007522 --> 0.007302).  Saving model ...
# Validation loss decreased (0.007302 --> 0.007193).  Saving model ...
# Validation loss decreased (0.007193 --> 0.007189).  Saving model ...
# Validation loss decreased (0.007189 --> 0.007093).  Saving model ...
# Validation loss decreased (0.007093 --> 0.006879).  Saving model ...
# Validation loss decreased (0.006879 --> 0.006717).  Saving model ...
# Validation loss decreased (0.006717 --> 0.006661).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# Validation loss decreased (0.006661 --> 0.006639).  Saving model ...
# Validation loss decreased (0.006639 --> 0.006634).  Saving model ...
# EarlyStopping counter: 1 out of 15
# EarlyStopping counter: 2 out of 15
# EarlyStopping counter: 3 out of 15
# EarlyStopping counter: 4 out of 15
# EarlyStopping counter: 5 out of 15
# EarlyStopping counter: 6 out of 15
# EarlyStopping counter: 7 out of 15
# EarlyStopping counter: 8 out of 15
# EarlyStopping counter: 9 out of 15
# EarlyStopping counter: 10 out of 15
# EarlyStopping counter: 11 out of 15
# EarlyStopping counter: 12 out of 15
# models/CSO_test_2
# Validation loss decreased (inf --> 0.011274).  Saving model ...
# Validation loss decreased (0.011274 --> 0.011274).  Saving model ...
# Validation loss decreased (0.011274 --> 0.011274).  Saving model ...
# Validation loss decreased (0.011274 --> 0.011274).  Saving model ...
# Validation loss decreased (0.011274 --> 0.011273).  Saving model ...
# Validation loss decreased (0.011273 --> 0.011272).  Saving model ...
# Validation loss decreased (0.011272 --> 0.011271).  Saving model ...
# Validation loss decreased (0.011271 --> 0.011269).  Saving model ...
# Validation loss decreased (0.011269 --> 0.011267).  Saving model ...
# Validation loss decreased (0.011267 --> 0.011264).  Saving model ...
# Validation loss decreased (0.011264 --> 0.011259).  Saving model ...
# Validation loss decreased (0.011259 --> 0.011253).  Saving model ...
# Validation loss decreased (0.011253 --> 0.011245).  Saving model ...
# Validation loss decreased (0.011245 --> 0.011232).  Saving model ...
# Validation loss decreased (0.011232 --> 0.011214).  Saving model ...
# Validation loss decreased (0.011214 --> 0.011186).  Saving model ...
# Validation loss decreased (0.011186 --> 0.011143).  Saving model ...
# Validation loss decreased (0.011143 --> 0.011075).  Saving model ...
# Validation loss decreased (0.011075 --> 0.010966).  Saving model ...
# Validation loss decreased (0.010966 --> 0.010795).  Saving model ...
# Validation loss decreased (0.010795 --> 0.010535).  Saving model ...
# Validation loss decreased (0.010535 --> 0.010172).  Saving model ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#      11 print(name)
#      13 model, opt, scheduler = get_model(init_dict_base,lr = 0.005,wd=0,device=device)
# ---> 15 train(model, opt, dataloader_train, dataloader_valid,
#      16       loss_fn, loss_fn_mae, run_name,
#      17       max_iter=max_iter, scheduler=scheduler, device=device)
#
# File /blue/hennig/jasongibson/clean_a2f/utils/training.py:183, in train(model, optimizer, dataloader_train, dataloader_valid, loss_fn, loss_fn_mae, run_name, max_iter, scheduler, device)
#     180     with open(run_name + ".torch", "wb") as f:
#     181         torch.save(results, f)
# --> 183 early_stopping(valid_avg_loss[0], model)
#     185 if early_stopping.early_stop:
#     186     print("Early stopping")
#
# File /blue/hennig/jasongibson/clean_a2f/utils/training.py:52, in EarlyStopping.__call__(self, val_loss, model)
#      49     else:
#      51         self.best_score = score
# ---> 52         self.save_checkpoint(val_loss, model)
#      53         self.counter = 0
#      55 elif self.region == 2:
#
# File /blue/hennig/jasongibson/clean_a2f/utils/training.py:94, in EarlyStopping.save_checkpoint(self, val_loss, model)
#      92 if self.verbose:
#      93     print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...',flush=True)
# ---> 94 torch.save(model.state_dict(), self.path+ f'{self.region}'+'.pt')
#      95 self.val_loss_min = val_loss
#
# File ~/.conda/envs/e3nn_env/lib/python3.9/site-packages/torch/serialization.py:379, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     377 if _use_new_zipfile_serialization:
#     378     with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 379         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     380         return
#     381 _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#
# File ~/.conda/envs/e3nn_env/lib/python3.9/site-packages/torch/serialization.py:484, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     482 pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     483 pickler.persistent_id = persistent_id
# --> 484 pickler.dump(obj)
#     485 data_value = data_buf.getvalue()
#     486 zip_file.write_record('data.pkl', data_value, len(data_value))
#
# File ~/.conda/envs/e3nn_env/lib/python3.9/site-packages/torch/serialization.py:467, in _save.<locals>.persistent_id(obj)
#     461 def persistent_id(obj):
#     462     # FIXME: the docs say that persistent_id should only return a string
#     463     # but torch store returns tuples. This works only in the binary protocol
#     464     # see
#     465     # https://docs.python.org/2/library/pickle.html#pickling-and-unpickling-external-objects
#     466     # https://github.com/python/cpython/blob/master/Lib/pickle.py#L527-L537
# --> 467     if torch.is_storage(obj):
#     468         storage_type = normalize_storage_type(type(obj))
#     469         obj_key = id_map.setdefault(obj._cdata, str(len(id_map)))
#
# File ~/.conda/envs/e3nn_env/lib/python3.9/site-packages/torch/__init__.py:291, in is_storage(obj)
#     272     r"""Returns True if `obj` is a PyTorch tensor.
#     273
#     274     Note that this function is simply doing ``isinstance(obj, Tensor)``.
#    (...)
#     286
#     287     """
#     288     return isinstance(obj, torch.Tensor)
# --> 291 def is_storage(obj):
#     292     r"""Returns True if `obj` is a PyTorch storage object.
#     293
#     294     Args:
#     295         obj (Object): Object to test
#     296     """
#     297     return type(obj) in _storage_classes
#
# KeyboardInterrupt:
